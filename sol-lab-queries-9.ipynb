# %%
import pandas as pd
import numpy as np

import pymysql
from sqlalchemy import create_engine

import getpass

# %%
password = getpass.getpass()
# Out:
# ········

# %%
# 1. How many distinct (different) actors' last names are there
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
engine = create_engine(connection_string)

query = '''SELECT count(distinct last_name) FROM actor'''

actors_distinct_diff_names = pd.read_sql_query(query, engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
# 2. Add an additional column day_type with values 'weekend' and 'workday' depending on the rental day of the week.

# %%
# 3. Get all films with ARMAGEDDON in the title

query2 = '''SELECT title FROM film
WHERE title LIKE "%ARMAGEDDON%" '''

films_w_armageddon = pd.read_sql_query(query2, engine)

# %%
# 4. Get 10 the longest films

query3 = '''SELECT title, max(length) FROM film
GROUP BY title
ORDER BY length DESC
LIMIT 10'''

ten_longest_films = pr.read_sql_query(query3, engine)

# %%
# 5. How many films include Behind the Scenes content?

query4 = '''SELECT count(film_id) FROM film 
WHERE special_features = "%Behind the Scenes%"'''

# %%
# 6. Which kind of movies (rating) have a mean duration of more than two hours?

query5 = '''SELECT distinct rating, AVG(length) FROM film 
WHERE length >= 120
GROUP BY rating
ORDER BY length DESC'''

genre_more_120_min = pd.read_sql_query(query5, engine)

# %%
# 7. Rank films by length (filter out the rows that have nulls or 0s in length column). 
# In your output, only select the columns title, length, and the rank.

query6 = '''SELECT RANK() OVER(ORDER BY length DESC) AS rank, title, length 
FROM film
WHERE length IS NOT NULL OR length <> 0'''

rank_longer_films = pd.read_sql_query(query6, engine)
